# %% [markdown]
# # Problem set 1
#
# The performance of a client-server system is strongly influenced by two major network characteristics: the bandwidth of the network (that is, how many bits it can transport in unit time) and the latency (that is, how many seconds it takes for the first bit of the message to get from the client to the server).
#
# In this problemset the latter feature, the latency, is practically investigated in the Internet network.
#
# Most entities in the Internet, call them nodes, that take part in the communication process obey the laws the IP protocols dictate and implement a layered software structure. Our investigation is in the network layer. Note the fact the messages to be sent are broken down to smaller segments, named IP packets, which are dressed up with additional necessary information to be routed to the right destination(s). The notion of IP address identifies a node in the network layer uniquely. Any nodes inside the network that take part in a given client-server communication process needs to decide how to forward IP packages accross them so the packets reach their destination. The rule of the thumb is to try be as efficient as possible.
#
#
# ## Problem 1.1
#
# An IP packet travelling between the client and the server will suffer from some latency. This delay is depending on many terms. Some of these terms vary in time some are constant. The terms include the ensamblement or processing of the packets, buffering delay when the forwarder node or its ports are loaded, and the propagation delay in the mediums between any adjacent nodes.
#
# The `ping` program allows you to send a test packet (ICMP request) to a server with a given location and see how long it takes to get there and back.
#
# Try and collect a set of servers for which the geographical location can be well approximated. It is best to use universities or govenmental portals since the location of their servers is known very accurately. Then using the `ping` measure how long it takes to get from your location to these known locations. From the data, plot the one-way transit time over the Internet as a function of distance.
#
# Draw conclusions from your plot. If necessary argue how you preprocess or filter your dataset.
#
# If you have an access and permissions to terminal computers located in a remote sites carry out the measurements to the same set of nodes and try compare your results.
#
# ## Problem 1.2
#
# Select few destination nodes used in P1.1 and measure the roud trip delay for long time (few weeks long). Plot and analyze the data try and find any remarks in the time evolution of the data that can be caused by human factor.

# %%
# Most American universities have their European servers based near Lucerne, Switzerland

# %%
import pandas as pd
import numpy as np
import subprocess

# %%
df = pd.read_csv('servers.csv')
df
# Out:
#          IP Address              domain      Country          Region/City  \
# 0       148.6.2.104           wigner.hu      Hungary             Budapest
# 1     157.181.1.232             elte.hu      Hungary             Budapest
# 2     193.231.20.15          ubbcluj.ro      Romania                 Cluj
# 3       193.226.5.7           utcluj.ro      Romania                 Cluj
# 4   129.187.255.151              tum.de      Germany  Garchingbei München
# 5     160.45.170.10        fu-berlin.de      Germany               Berlin
# 6      130.75.2.151     uni-hannover.de      Germany             Hannover
# 7    131.152.228.33           unibas.ch  Switzerland                Basel
# 8      193.49.39.51  universite-lyon.fr       France                 Lyon
# 9      194.117.3.27      www.ulisboa.pt     Portugal               Lisboa
# 10    128.232.132.8           cam.ac.uk           UK                Coton
# 11  129.215.235.216            ed.ac.uk           UK            Edinburgh
# 12   140.180.223.42   www.princeton.edu          USA            Princeton
# 13       23.185.0.1     www.harvard.edu  Switzerland              Lucerne
# 14   164.67.228.152        www.ucla.edu          USA          Los Angeles
# 15   133.162.67.133       www.ynu.ac.jp        Japan                Tokyo
# 16    147.46.10.174      www.useoul.edu   SouthKorea                Seoul
# 17    50.19.226.237         web.iit.edu          USA              Ashburn
# 18   143.107.158.19        fearp.usp.br       Brazil            Sao Paulo
# 19     200.89.76.16           uchile.cl        Chile             Santiago
# 20     43.245.43.59      unimelb.edu.au    Australia               Sydney
# 21     80.96.21.209           unibuc.ro      Romania            Bucharest
#
#         lat       lon                                 ISP/Organization
# 0   47.4980   19.0399                 MTA Wigner Fizikai Kutatokozpont
# 1   47.4839   19.0597              Eotvos Lorand Universityof Sciences
# 2   46.7667   23.6000                       Romanian Education Network
# 3   46.7727   23.5864                       Romanian Education Network
# 4   48.2490   11.6510                            Leibniz Rechenzentrum
# 5   52.5244   13.4105                        Freie Universitaet Berlin
# 6   52.3705    9.7332  Gottfried Wilhelm Leibniz Universitaet Hannover
# 7   47.5584    7.5733                               Universitaet Basel
# 8   45.7485    4.8467                            PresUniversitede Lyon
# 9   38.7167   -9.1333         Fundacao Paraa Cienciaea Tecnologia I.P.
# 10  52.2106    0.0609                          University of Cambridge
# 11  55.9521   -3.1965                      The University of Edinburgh
# 12  40.3675  -74.6695                             Princeton University
# 13  46.9516    8.0172                                           Fastly
# 14  34.0522 -118.2437             University of California Los Angeles
# 15  35.6895  139.6917                                  Fujitsu Limited
# 16  37.5660  126.9784                        Seoul National University
# 17  39.0437  -77.4875                                  Amazon.com Inc.
# 18 -21.1775  -47.8103                        Universidade de Sao Paulo
# 19 -33.4263  -70.5666                             Universidad de Chile
# 20 -33.8678  151.2073                                    Squiz Pty Ltd
# 21  44.4323   26.1063                      Universitatea din Bucuresti

# %%
import json
from subprocess import check_output

# Get my ip and my location
resp = check_output(["curl", "https://ipinfo.io"])
result = json.loads(resp.decode('utf8'))
my_ip = result['ip']
my_loc_lat, my_loc_lon = result['loc'].split(',')
my_loc_lat = float(my_loc_lat)
my_loc_lon = float(my_loc_lon)

# %%
import folium

mymap = folium.Map(
  location=[my_loc_lat, my_loc_lon],
  zoom_start=2,
  tiles='cartodbpositron'
)

folium.Marker([my_loc_lat, my_loc_lon], popup='My location').add_to(mymap)

for index, row in df.iterrows():
    folium.Marker(
      [row['lat'], row['lon']],
      popup=row['domain']
    ).add_to(mymap)

mymap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Run all processes asynchronously
from subprocess import Popen, PIPE
running = []

for k in range(len(df)):
    filename = "pings-" + df[['domain']].values[k][0] + ".pingdata"
    cmd = "if [ -f " + filename + " ]; then\n"
    cmd += "rm -v " + filename + "\n"
    cmd += "fi"
    cmd = ''.join(cmd)
    subprocess.call(cmd, shell=True)

    cmd = 'printf "#My ip: {}\\n#My lat: {}\\n#My lon: {}\\n"'.format(my_ip, my_loc_lat, my_loc_lon)
    cmd += " > " + filename
    subprocess.call(cmd, shell=True)

    # Ping for a specific time interval
    cmd = ["ping", df[['IP Address']].values[k][0], "-t30", ">>", filename]
    cmd = ' '.join(cmd)

    # https://stackoverflow.com/a/636601/1708155
    running.append(
        {
            'command': cmd,
            'process': Popen(cmd, shell=True)
        }
    )
    
import time
while running:
    for idx, record in enumerate(running):
        retcode = record['process'].poll()
        if retcode is not None: # Process finished.
            running.remove(record)
            print("Command " + record['command'] + " finished.")
            break
        else: # No process is done, wait a bit and check again.
            time.sleep(.1)
            continue

    if retcode != 0 and idx < len(running):
        print("Command " + running[idx]['command'] + " failed.")
# Out:
# Command ping 80.96.21.209 -t30 >> pings-unibuc.ro.pingdata failed.
# Command ping 80.96.21.209 -t30 >> pings-unibuc.ro.pingdata failed.
# Command ping 80.96.21.209 -t30 >> pings-unibuc.ro.pingdata failed.
# Command ping 80.96.21.209 -t30 >> pings-unibuc.ro.pingdata failed.
# Command ping 80.96.21.209 -t30 >> pings-unibuc.ro.pingdata failed.
# Command ping 80.96.21.209 -t30 >> pings-unibuc.ro.pingdata failed.
# Command ping 80.96.21.209 -t30 >> pings-unibuc.ro.pingdata failed.
# Command ping 80.96.21.209 -t30 >> pings-unibuc.ro.pingdata failed.
# Command ping 80.96.21.209 -t30 >> pings-unibuc.ro.pingdata failed.
# Command ping 80.96.21.209 -t30 >> pings-unibuc.ro.pingdata failed.
# Command ping 80.96.21.209 -t30 >> pings-unibuc.ro.pingdata failed.
# Command ping 80.96.21.209 -t30 >> pings-unibuc.ro.pingdata failed.
# Command ping 80.96.21.209 -t30 >> pings-unibuc.ro.pingdata failed.
# Command ping 193.226.5.7 -t30 >> pings-utcluj.ro.pingdata finished.
# Command ping 148.6.2.104 -t30 >> pings-wigner.hu.pingdata finished.
# Command ping 157.181.1.232 -t30 >> pings-elte.hu.pingdata finished.
# Command ping 193.231.20.15 -t30 >> pings-ubbcluj.ro.pingdata finished.
# Command ping 129.187.255.151 -t30 >> pings-tum.de.pingdata finished.
# Command ping 130.75.2.151 -t30 >> pings-uni-hannover.de.pingdata finished.
# Command ping 160.45.170.10 -t30 >> pings-fu-berlin.de.pingdata finished.
# Command ping 131.152.228.33 -t30 >> pings-unibas.ch.pingdata finished.
# Command ping 193.49.39.51 -t30 >> pings-universite-lyon.fr.pingdata finished.
# Command ping 128.232.132.8 -t30 >> pings-cam.ac.uk.pingdata finished.
# Command ping 194.117.3.27 -t30 >> pings-www.ulisboa.pt.pingdata finished.
# Command ping 129.215.235.216 -t30 >> pings-ed.ac.uk.pingdata finished.
# Command ping 140.180.223.42 -t30 >> pings-www.princeton.edu.pingdata finished.
# Command ping 23.185.0.1 -t30 >> pings-www.harvard.edu.pingdata finished.
# Command ping 133.162.67.133 -t30 >> pings-www.ynu.ac.jp.pingdata finished.
# Command ping 164.67.228.152 -t30 >> pings-www.ucla.edu.pingdata finished.
# Command ping 147.46.10.174 -t30 >> pings-www.useoul.edu.pingdata finished.
# Command ping 50.19.226.237 -t30 >> pings-web.iit.edu.pingdata finished.
# Command ping 143.107.158.19 -t30 >> pings-fearp.usp.br.pingdata finished.
# Command ping 43.245.43.59 -t30 >> pings-unimelb.edu.au.pingdata finished.
# Command ping 200.89.76.16 -t30 >> pings-uchile.cl.pingdata finished.
# Command ping 80.96.21.209 -t30 >> pings-unibuc.ro.pingdata finished.

# %%
# !ls -lah
# Out:
# total 13784
# drwxr-xr-x  28 nagydaniel  staff   896B Oct 30 12:29 .
# drwxr-xr-x  59 nagydaniel  staff   1.8K Oct 19 15:55 ..
# drwxr-xr-x   3 nagydaniel  staff    96B Oct 29 17:50 .ipynb_checkpoints
# -rw-r--r--@  1 nagydaniel  staff   6.6M Sep 10 16:05 EVOLUTION AND STRUCTURE OF THE INTERNET -MANTESHWER.pdf
# -rw-r--r--@  1 nagydaniel  staff    46K Oct 30 12:29 Problemset_1.ipynb
# -rw-r--r--   1 nagydaniel  staff   2.1K Oct 30 12:29 pings-cam.ac.uk.pingdata
# -rw-r--r--   1 nagydaniel  staff   2.2K Oct 30 12:29 pings-ed.ac.uk.pingdata
# -rw-r--r--   1 nagydaniel  staff   2.1K Oct 30 12:29 pings-elte.hu.pingdata
# -rw-r--r--   1 nagydaniel  staff   2.1K Oct 30 12:29 pings-fearp.usp.br.pingdata
# -rw-r--r--   1 nagydaniel  staff   2.1K Oct 30 12:29 pings-fu-berlin.de.pingdata
# -rw-r--r--   1 nagydaniel  staff   2.2K Oct 30 12:29 pings-tum.de.pingdata
# -rw-r--r--   1 nagydaniel  staff   2.1K Oct 30 12:29 pings-ubbcluj.ro.pingdata
# -rw-r--r--   1 nagydaniel  staff   2.1K Oct 30 12:29 pings-uchile.cl.pingdata
# -rw-r--r--   1 nagydaniel  staff   2.1K Oct 30 12:29 pings-uni-hannover.de.pingdata
# -rw-r--r--   1 nagydaniel  staff   2.2K Oct 30 12:29 pings-unibas.ch.pingdata
# -rw-r--r--   1 nagydaniel  staff   2.1K Oct 30 12:29 pings-unibuc.ro.pingdata
# -rw-r--r--   1 nagydaniel  staff   2.1K Oct 30 12:29 pings-unimelb.edu.au.pingdata
# -rw-r--r--   1 nagydaniel  staff   2.1K Oct 30 12:29 pings-universite-lyon.fr.pingdata
# -rw-r--r--   1 nagydaniel  staff   2.0K Oct 30 12:29 pings-utcluj.ro.pingdata
# -rw-r--r--   1 nagydaniel  staff   2.1K Oct 30 12:29 pings-web.iit.edu.pingdata
# -rw-r--r--   1 nagydaniel  staff   2.0K Oct 30 12:29 pings-wigner.hu.pingdata
# -rw-r--r--   1 nagydaniel  staff   2.0K Oct 30 12:29 pings-www.harvard.edu.pingdata
# -rw-r--r--   1 nagydaniel  staff   2.2K Oct 30 12:29 pings-www.princeton.edu.pingdata
# -rw-r--r--   1 nagydaniel  staff   2.2K Oct 30 12:29 pings-www.ucla.edu.pingdata
# -rw-r--r--   1 nagydaniel  staff   2.1K Oct 30 12:29 pings-www.ulisboa.pt.pingdata
# -rw-r--r--   1 nagydaniel  staff   2.1K Oct 30 12:29 pings-www.useoul.edu.pingdata
# -rw-r--r--   1 nagydaniel  staff   2.2K Oct 30 12:29 pings-www.ynu.ac.jp.pingdata
# -rw-r--r--@  1 nagydaniel  staff   1.9K Oct 29 21:06 servers.csv

# %%
# !cat pings-wigner.hu.pingdata | grep time=
# Out:
# 64 bytes from 148.6.2.104: icmp_seq=0 ttl=54 time=3.520 ms
# 64 bytes from 148.6.2.104: icmp_seq=1 ttl=54 time=3.963 ms
# 64 bytes from 148.6.2.104: icmp_seq=2 ttl=54 time=4.179 ms
# 64 bytes from 148.6.2.104: icmp_seq=3 ttl=54 time=2.964 ms
# 64 bytes from 148.6.2.104: icmp_seq=4 ttl=54 time=3.871 ms
# 64 bytes from 148.6.2.104: icmp_seq=5 ttl=54 time=3.888 ms
# 64 bytes from 148.6.2.104: icmp_seq=6 ttl=54 time=3.883 ms
# 64 bytes from 148.6.2.104: icmp_seq=7 ttl=54 time=3.835 ms
# 64 bytes from 148.6.2.104: icmp_seq=8 ttl=54 time=3.267 ms
# 64 bytes from 148.6.2.104: icmp_seq=9 ttl=54 time=3.838 ms
# 64 bytes from 148.6.2.104: icmp_seq=10 ttl=54 time=3.846 ms
# 64 bytes from 148.6.2.104: icmp_seq=11 ttl=54 time=3.862 ms
# 64 bytes from 148.6.2.104: icmp_seq=12 ttl=54 time=3.762 ms
# 64 bytes from 148.6.2.104: icmp_seq=13 ttl=54 time=3.211 ms
# 64 bytes from 148.6.2.104: icmp_seq=14 ttl=54 time=3.834 ms
# 64 bytes from 148.6.2.104: icmp_seq=15 ttl=54 time=5.387 ms
# 64 bytes from 148.6.2.104: icmp_seq=16 ttl=54 time=4.296 ms
# 64 bytes from 148.6.2.104: icmp_seq=17 ttl=54 time=5.604 ms
# 64 bytes from 148.6.2.104: icmp_seq=18 ttl=54 time=3.189 ms
# 64 bytes from 148.6.2.104: icmp_seq=19 ttl=54 time=4.415 ms
# 64 bytes from 148.6.2.104: icmp_seq=20 ttl=54 time=3.861 ms
# 64 bytes from 148.6.2.104: icmp_seq=21 ttl=54 time=3.864 ms
# 64 bytes from 148.6.2.104: icmp_seq=22 ttl=54 time=4.347 ms
# 64 bytes from 148.6.2.104: icmp_seq=23 ttl=54 time=3.112 ms
# 64 bytes from 148.6.2.104: icmp_seq=24 ttl=54 time=3.761 ms
# 64 bytes from 148.6.2.104: icmp_seq=25 ttl=54 time=3.861 ms
# 64 bytes from 148.6.2.104: icmp_seq=26 ttl=54 time=3.881 ms
# 64 bytes from 148.6.2.104: icmp_seq=27 ttl=54 time=3.669 ms
# 64 bytes from 148.6.2.104: icmp_seq=28 ttl=54 time=3.011 ms
# 64 bytes from 148.6.2.104: icmp_seq=29 ttl=54 time=3.835 ms

# %%
# !ALMA="alma" && echo ${ALMA:-"KUTYA"}
# Out:
# alma
